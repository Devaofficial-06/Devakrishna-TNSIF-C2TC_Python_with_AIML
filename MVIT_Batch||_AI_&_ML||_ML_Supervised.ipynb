# %% [markdown]
# <a href="https://colab.research.google.com/github/Devaofficial-06/Devakrishna-TNSIF-C2TC_Python_with_AIML/blob/main/MVIT_Batch%7C%7C_AI_%26_ML%7C%7C_ML_Supervised.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
